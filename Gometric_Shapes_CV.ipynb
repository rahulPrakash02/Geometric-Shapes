# %%
import numpy as np
import cv2
img = cv2.imread("/content/Test 1.jpg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EF5445A50>

# %%
img1 = cv2.imread("/content/Test 1.jpg", 0)
#displays grayscale image

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=1098x460 at 0x7F3EE86A8C50>

# %%
cv2.imwrite('saved_img.png', img1)
# Out:
# True

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 1.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF5BDB50>
# 4

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 2.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF64BF10>
# 8

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 3.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF5C3B50>
# 5

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 4.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EE85E8590>
# 4

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 5.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF5CA310>
# 5

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 6.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF674F90>
# 4

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 7.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF5EE2D0>
# 3

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 8.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF5BDA90>
# 7

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 9.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF63B690>
# 5

# %%
import numpy as np
import cv2

img = cv2.imread("/content/Test 10.jpg")
cv2_imshow(img)
imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(imgGrey, 240, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered = []
low = 1000
high = 100000
for contour in contours:
  area = cv2.contourArea(contour)
  if low<area and area<high:
    filtered.append(contour)

print(len(filtered))
# Out:
# <PIL.Image.Image image mode=RGB size=1098x460 at 0x7F3EDF5C3990>
# 6
